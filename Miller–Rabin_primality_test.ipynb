# %% [markdown]
# [View in Colaboratory](https://colab.research.google.com/github/wagyan/math/blob/master/Miller%E2%80%93Rabin_primality_test.ipynb)

# %%
import random
import math
import numpy as np

def isPrime(num):
  k=100
  d=mkd(num)  
  s=int(math.log2(num/d))
  for i in range(k):
    a=random.randint(1,num-1)
    ard=pow(a,d,num)
    if not(ard==1):
      c=0
      for r in range(0, s):
        if not(ard == num-1): c=c+1
        ard=(ard*ard) %num
      if c==s: return False
  return True

def mkd(n):
  d=n-1
  while d&1==0:
    d>>=1
  return d


for a in range(13):
  for b in range(13):
    for c in range(13):
      x=int(str(a+1) + str(b+1) + str(c+1))
      if isPrime(x)==True: print(x)
# Out:
# 113
# 127
# 1213
# 131
# 137
# 139
# 149
# 151
# 157
# 1511
# 163
# 167
# 1613
# 173
# 179
# 181
# 1811
# 191
# 193
# 197
# 199
# 1913
# 1103
# 1109
# 1117
# 11113
# 1123
# 1129
# 11213
# 11311
# 211
# 2111
# 2113
# 223
# 227
# 229
# 2213
# 233
# 239
# 2311
# 241
# 2411
# 251
# 257
# 263
# 269
# 271
# 277
# 2711
# 2713
# 281
# 283
# 293
# 21011
# 21013
# 2111
# 2113
# 2129
# 21211
# 2131
# 2137
# 21313
# 311
# 313
# 317
# 331
# 337
# 3313
# 347
# 349
# 3413
# 353
# 359
# 3511
# 367
# 3613
# 373
# 379
# 383
# 389
# 397
# 3911
# 3109
# 31013
# 3119
# 3121
# 3137
# 419
# 4111
# 421
# 4211
# 431
# 433
# 439
# 443
# 449
# 457
# 4513
# 461
# 463
# 467
# 479
# 487
# 4813
# 491
# 499
# 41011
# 4111
# 41113
# 4127
# 4129
# 41213
# 4133
# 4139
# 5113
# 521
# 523
# 541
# 547
# 5413
# 557
# 563
# 569
# 571
# 577
# 5711
# 587
# 5813
# 593
# 599
# 5101
# 5107
# 5113
# 5119
# 613
# 617
# 619
# 6113
# 6211
# 631
# 6311
# 641
# 643
# 647
# 653
# 659
# 661
# 673
# 677
# 683
# 691
# 6911
# 6101
# 6113
# ...
